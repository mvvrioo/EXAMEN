# %% [markdown]
# <a href="https://colab.research.google.com/github/mvvrioo/EXAMEN/blob/main/Mario_Torres_sigla_curso_004V_VESPERTINA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
depa=[['Piso  1', 'D','D','D','D'],
      ['Piso  2', 'D','D','D','D'],
      ['Piso  3', 'D','D','D','D'],
      ['Piso  4', 'D','D','D','D'],
      ['Piso  5', 'D','D','D','D'],
      ['Piso  6', 'D','D','D','D'],
      ['Piso  7', 'D','D','D','D'],
      ['Piso  8', 'D','D','D','D'],
      ['Piso  9', 'D','D','D','D'],
      ['Piso 10', 'D','D','D','D']
      ]
totala=0
totalb=0
totalc=0
totald=0
tipor=[]
pisor=[]
counta = 0
countb= 0
countc=0
countd=0
rut=[]
total=[]
precios=[3800,3200,3100,3000,3400]
f = {"A":1,"B":2,"C":3,"D":4}

def mostrar():
  print("\tA B C D ")
  for i in reversed(depa):
      print(" ".join(i))

def comprar():
    print("\tindique que opcion desea")
    rutg=int(input("Ingrese su RUT sin puntos ni guiones\n"))
    rut.append(rutg)
    print("!operacion realizaca correctamente!")
    buypiso=int(input("Ingrese el numero del piso que desea comprar\n"))
    pisor.append(buypiso)
    buytipo=str(input("Ingrese el tipo de piso(A,B,C,D) que desea comprar (CON MAYUSCULA LA LETRA INGRESADA)\n"))
    tipor.append(buytipo)
    if buytipo=="A":
      global counta, totala
      counta = counta= counta+1
      totala = totala = totala+3800
    if buytipo=="B":
      global countb, totalb
      countb = countb= countb+1
      totalb = totalb = totalb+3000
    if buytipo=="C":
      global countc, totalc
      countc = countc= countc+1
      totalc = totalc = totalc+2800
    if buytipo=="D":
      global countd, totald
      countd = countd= countd+1
      totald = totald = totald+3500
    conve= f.get(buytipo)
    if depa[buypiso-1][conve]=="D":
            depa[buypiso-1][conve]="x"
            print("-------------------------------------------------------------")
            print("!FELICIDADES! Ha comprado exitosamente su departamento")
            print("-------------------------------------------------------------")
    else:
      print("--------------------------------------")
      print("!El departamento no esta dispobile!")
      print("--------------------------------------")

def compradores():
        print(f"--------------------------------\nRUTS COMPRADORES: {rut},\nPISOS COMPRADORES:{pisor}\nTIPO COMPRADORES:{tipor}--------------------------------\n")

def ganancias():
  print("------------------------------------------------------")
  print("Tipo de Departamento \tCantidad     Total")
  print(f"TIPO A 3.800 UF\t\t    {counta}        {totala}UF")
  print(f"TIPO B 3.000 UF\t\t    {countb}        {totalb}UF")
  print(f"TIPO C 2.800 UF\t\t    {countc}        {totalc}UF")
  print(f"TIPO D 3.500 UF\t\t    {countd}        {totald}UF")
  print(f"TOTAL\t\t\t    {counta+countb+countc+countd}        {totala+totalb+totalc+totald}UF")
  print("------------------------------------------------------")

def salida():
  print("------------------------------------------")
  print("\tUsted ha salido del sistema")
  print("\t      Mario Torres")
  print("\t       13/07/23")
  print("------------------------------------------")



while True:
  print("\t\tBIENVENIDO")
  print("\tInmobiliaria Casa Feliz\n")
  sistema = int(input("--------------------------------------\n(0)Comprar departamento\n(1)Mostrar departamentos disponible\n(2)Ver listado de compradores\n(3)Mostrar ganancias totales\n(4)Salir\n--------------------------------------\n"))

  if sistema==0:
    mostrar()
    comprar()


  if sistema==1:
      mostrar()


  if sistema==2:
      compradores()


  if sistema==3:
      ganancias()


  if sistema==4:
      salida()
      break
# Out:
# 		BIENVENIDO
# 	Inmobiliaria Casa Feliz
#
# --------------------------------------
# (0)Comprar departamento
# (1)Mostrar departamentos disponible
# (2)Ver listado de compradores
# (3)Mostrar ganancias totales
# (4)Salir
# --------------------------------------
# 4
# ------------------------------------------
# 	Usted ha salido del sistema
# 	      Mario Torres
# 	       13/07/23
# ------------------------------------------
